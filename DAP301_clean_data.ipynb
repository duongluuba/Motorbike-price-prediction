# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pickle


class PickleableLink:
    def __init__(self, link_data):
        # Exclude non-picklable elements here
        self.picklable_data = link_data
        
linkList = []

driver=webdriver.Chrome()
for i in range(1,4):
    driver.get(f"https://xe.chotot.com/mua-ban-xe-may-ha-noi?page={i}")
    links_raw = driver.find_elements(By.CLASS_NAME, "AdItem_adItem__gDDQT")
    for link in links_raw:
        http = link.get_attribute('href')
        pickleable_link = PickleableLink(http)
        linkList.append(pickleable_link)


with open("test2", "wb") as fp:   #Pickling
    pickle.dump(linkList, fp)

# %%
import pickle

clean_list = []

class PickleableLink:
    def __init__(self, link_data):
        self.picklable_data = link_data

# Unpickle the data
with open("test2", "rb") as fp:
    link_list = pickle.load(fp)

# Extract and print the URLs
for link_object in link_list:
    url = link_object.picklable_data
    modified_url = url.rstrip(']')
    clean_list.append(modified_url)

with open("clean_url", "wb") as fp:   #Pickling
    pickle.dump(clean_list, fp)

# %%
import json
import pickle

class PickleableLink:
    def __init__(self, link_data):
        self.picklable_data = link_data

class CustomEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, PickleableLink):
            return {'picklable_data': obj.picklable_data}
        return super().default(obj)

# Unpickle the data
with open("clean_url", "rb") as fp:
    link_list = pickle.load(fp)

# Serialize to JSON with the custom encoder
json_data = json.dumps(link_list, cls=CustomEncoder)

# Save JSON to a file
with open("cleaned_data.json", "w") as json_file:
    json_file.write(json_data)

# %%
with open("cleaned_data.json", "rb") as fp:   # Unpickling
    linkItem = json.load(fp)
    print(linkItem)
# Out:
# ['https://xe.chotot.com/mua-ban-xe-may-quan-nam-tu-liem-ha-noi/113558898.htm#px=SR-stickyad-[PO-1][PL-top', 'https://xe.chotot.com/mua-ban-xe-may-quan-nam-tu-liem-ha-noi/102308922.htm#px=SR-stickyad-[PO-2][PL-top', 'https://xe.chotot.com/mua-ban-xe-may-quan-nam-tu-liem-ha-noi/102291377.htm#px=SR-stickyad-[PO-3][PL-top', 'https://xe.chotot.com/mua-ban-xe-may-quan-nam-tu-liem-ha-noi/102291948.htm#px=SR-stickyad-[PO-4][PL-top', 'https://xe.chotot.com/mua-ban-xe-may-quan-nam-tu-liem-ha-noi/102227615.htm#px=SR-stickyad-[PO-5][PL-top', 'https://xe.chotot.com/mua-ban-xe-may-quan-nam-tu-liem-ha-noi/112261939.htm', 'https://xe.chotot.com/mua-ban-xe-may-quan-dong-da-ha-noi/112190008.htm', 'https://xe.chotot.com/mua-ban-xe-may-quan-nam-tu-liem-ha-noi/110849544.htm', 'https://xe.chotot.com/mua-ban-xe-may-quan-thanh-xuan-ha-noi/104335301.htm', 'https://xe.chotot.com/mua-ban-xe-may-quan-nam-tu-liem-ha-noi/57195418.htm', 'https://xe.chotot.com/mua-ban-xe-may-quan-nam-tu-liem-ha-noi/87657744.htm', '
# ...

# %%
with open("cleaned_data.json", "rb") as fp:   # Unpickling
    linkItem = json.load(fp)
#datacleaning duplicate cleaning...


title = []
price = []
timeStamp = []
hang= []
dong = []
namdangki=  []
soKM = []
tinhTrang = []
loaiXe = []
dungTich = []
xuatXu = []
chinhSachBH = []
TrongLuong = []    
for link in linkItem:
    driver.get(link)
    
    # Title
    titles = driver.find_elements(By.XPATH, "//h1[@class='AdDecriptionVeh_adTitle__vEuKD' and @itemprop='name']")
    for til in titles:
        title.append(til.text)

    # Price
    prices = driver.find_elements(By.XPATH, "//h1[@class='AdDecriptionVeh_adTitle__vEuKD' and @itemprop='name']")
    for til in titles:
        title.append(til.text)
    

    price.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'price')]").text)
    #timeStamp.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'name')]").text)
    hang.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'motorbikebrand')]").text)
    dong.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'motorbikemodel')]").text)
    namdangki.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'regdate')]").text)
    soKM.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'mileage_v2')]").text)
    tinhTrang.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'condition_ad')]").text)
    loaiXe.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'motorbiketype')]").text)
    dungTich.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'motorbikecapacity')]").text)
    xuatXu.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'motorbikeorigin')]").text)
    chinhSachBH.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'veh_warranty_policy')]").text)
    TrongLuong.append(driver.find_elements(By.XPATH, "//span[contains(@itemprop, 'veh_unladen_weight')]").text)

# %%
title
# Out:
# ['honda lead màu vang kem đẹp leng keng',
#  'Vespa 125 chính chủ cần bán',
#  'Liberty 125 ie biển 29 chính chủ',
#  'Vespa 125 chính chủ',
#  'Thanh lý Vespa/ Liberty giá siêu rẻ',
#  'Winner V3, 2023, zin 100%, còn bảo hành hãng',
#  'Xe cực chất, SH 125 ABS 2019 xám xi măng cực đẹp.',
#  'xe ẽcter đk 2018 máy zin mowis 99%',
#  'THU MUA hoặc TRAO ĐỔI với tất cả các loại XE',
#  'Honda Air Blade 2013 mới nguyên bản đẹp Long lanh',
#  'AIRBLADE 125 FI ĐEN NHÁM 2016',
#  'VISITOR PHOENIX 175 2 MÁY-PÔ,MÁY NỔ TÊ TÁI ĐK 2020',
#  'HONDA PCX 125 MÀU VÀNG ĐỒNG BIỂN 29H ĐK 2016',
#  'Honda RSX 110 chính chủ trung niên sử dụng giữ',
#  'Chào bán Honda ablet bản spost',
#  'Cửa Hàng XE MÁY ANH LÊ Chuyên Xe SH VESPA LIBERTY',
#  'GPX Legend 200 biển 29 đẹp lướt.pkl moto classic',
#  'HONDA LEAD 125 ĐÈN NÉT MÀU XÁM GHI 2023',
#  '2021 Exciter 150cc. Chính chủ sd, bao sang tên',
#  'Honda Winner X biển 29- lướt- đẹp chất 2023',
#  'Xe Máy Nam Thi Airblade 125 bản Sport Zin chất đep',
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# Initialize WebDriver
driver = webdriver.Chrome()

# Example URL
url = "https://example.com"

# Navigate to the URL
driver.get(url)

# Search for the element with the specified class and itemprop
element = driver.find_element(By.XPATH, "//h1[@class='AdDecriptionVeh_adTitle__vEuKD' and @itemprop='name']")

# Print the text content of the found element
print(element.text)

# Close the WebDriver
driver.quit()
